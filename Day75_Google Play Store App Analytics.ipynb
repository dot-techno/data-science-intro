# %% [markdown]
# ## Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# ## About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Read the Dataset

# %%
df_apps = pd.read_csv('data/apps.csv')
print(df_apps.shape)
df_apps.sample( n=5)
# Out:
# (10841, 12)
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 1114  Random Chat App with Strangers     DATING    3.00        2     16.00
# 1704                               F      TOOLS     NaN        6      4.90
# 3036                Ek Onkar Mantras  LIFESTYLE    4.90       82      5.00
# 5365                Adivina el Emoji       GAME     NaN     2536     32.00
# 1800                     Wireless BP    MEDICAL    1.80       30      0.87
#
#      Installs  Type Price Content_Rating     Genres     Last_Updated  \
# 1114      100  Free     0     Mature 17+     Dating    July 17, 2018
# 1704      500  Free     0       Everyone      Tools     May 15, 2018
# 3036    5,000  Free     0       Everyone  Lifestyle   August 7, 2016
# 5365  100,000  Free     0       Everyone     Trivia  October 2, 2016
# 1800      500  Free     0       Everyone    Medical     May 27, 2016
#
#        Android_Ver
# 1114  4.0.3 and up
# 1704    4.0 and up
# 3036    4.1 and up
# ...

# %%
# drop last_udpated and android_ver columns -- not needed for analysis
df_apps.drop(['Last_Updated','Android_Ver'],axis=1, inplace=True)
df_apps.sample(n=5)
# Out:
#                                   App             Category  Rating   Reviews  \
# 10789              WhatsApp Messenger        COMMUNICATION    4.40  69119316
# 3918                  BK News Channel        VIDEO_PLAYERS    4.60       277
# 7214   AndStream - Streaming Download        VIDEO_PLAYERS    4.30     38607
# 1855                       A & B Taxi  MAPS_AND_NAVIGATION    4.10        41
# 2051                    DX Spots Free                TOOLS    4.50        46
#
#        Size_MBs       Installs  Type Price Content_Rating  \
# 10789      3.50  1,000,000,000  Free     0       Everyone
# 3918       6.80         10,000  Free     0       Everyone
# 7214       2.90      1,000,000  Free     0       Everyone
# 1855      25.00          1,000  Free     0       Everyone
# 2051      24.00          1,000  Free     0       Everyone
#
#                         Genres
# 10789            Communication
# 3918   Video Players & Editors
# 7214   Video Players & Editors
# ...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
#missing values
print(f"Missing values in dataset: {df_apps.isna().values.sum()}")

#sample of rows with missing ratings
df_apps[df_apps.Rating.isna()].sample(n=5)
# Out:
# Missing values in dataset: 1475
#                                                     App             Category  \
# 119      USMLE CK Clinical Knowledge Flashcards 2018 Ed               FAMILY
# 88                                               EW PDF  BOOKS_AND_REFERENCE
# 605   AS - Diario online deportivo. Fútbol, motor y más   NEWS_AND_MAGAZINES
# 1514                                    FH Kufstein App               FAMILY
# 429                                              MPS CL                TOOLS
#
#       Rating  Reviews  Size_MBs Installs  Type Price Content_Rating  \
# 119      NaN        0      3.60        5  Free     0       Everyone
# 88       NaN        0      8.70        5  Free     0       Everyone
# 605      NaN        0      6.00       50  Free     0       Everyone
# 1514     NaN        9     20.00      500  Free     0       Everyone
# 429      NaN        1      3.20       10  Free     0       Everyone
#
#                  Genres
# 119           Education
# ...

# %%
df_apps_clean = df_apps.dropna()
print(df_apps_clean.shape)
df_apps_clean.sample(n=3)
# Out:
# (9367, 10)
#                                   App       Category  Rating  Reviews  \
# 10658                 Jetpack Joyride           GAME    4.40  4637439
# 6333   TANGEDCO Mobile App (Official)       BUSINESS    3.30     2915
# 3509                   Flud (Ad free)  VIDEO_PLAYERS    4.80     5639
#
#        Size_MBs     Installs  Type  Price Content_Rating  \
# 10658     96.00  100,000,000  Free      0   Everyone 10+
# 6333       3.30      500,000  Free      0       Everyone
# 3509       4.65       10,000  Paid  $1.49       Everyone
#
#                         Genres
# 10658                   Arcade
# 6333                  Business
# 3509   Video Players & Editors

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
dup_rows = df_apps_clean[df_apps_clean.duplicated()]
print(dup_rows.shape)
dup_rows.sample(n=10)
# Out:
# (476, 10)
#                                                 App            Category  \
# 6445                                 Comedy Central       ENTERTAINMENT
# 7357                         Udemy - Online Courses           EDUCATION
# 5053                   Vaniday - Beauty Booking App           LIFESTYLE
# 9973                     PJ Masks: Moonlight Heroes              FAMILY
# 9853  Nike Training Club - Workouts & Fitness Plans  HEALTH_AND_FITNESS
# 9181                   Galaxy Attack: Alien Shooter                GAME
# 3894       Girls Live Chat - Free Text & Video Chat              DATING
# 6498                          Beautiful Widgets Pro     PERSONALIZATION
# 7517  Postmates Food Delivery: Order Eats & Alcohol      FOOD_AND_DRINK
# 8095                                         The CW       ENTERTAINMENT
#
#       Rating  Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 6445    3.90    22378     19.00   1,000,000  Free      0           Teen
# ...

# %%
# check one example of duplication
df_apps_clean[df_apps_clean.App == 'OkCupid Dating']
# Out:
#                  App Category  Rating  Reviews  Size_MBs    Installs  Type  \
# 9440  OkCupid Dating   DATING    4.10   285726     15.00  10,000,000  Free
# 9441  OkCupid Dating   DATING    4.10   285726     15.00  10,000,000  Free
# 9442  OkCupid Dating   DATING    4.10   285838     15.00  10,000,000  Free
#
#      Price Content_Rating  Genres
# 9440     0     Mature 17+  Dating
# 9441     0     Mature 17+  Dating
# 9442     0     Mature 17+  Dating

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App','Type','Price']) # keep all columns still keeps multiples of an app with # of reviews the only difference between the records

# %%
# check if duplicates are gone
df_apps_clean[df_apps_clean.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
# sort by rating values in descending order and see top few to get top apps by rating
df_apps_clean.sort_values(by='Rating',ascending=False).head()
# Out:
#                       App     Category  Rating  Reviews  Size_MBs Installs  \
# 21    KBA-EZ Health Guide      MEDICAL    5.00        4     25.00        1
# 1230         Sway Medical      MEDICAL    5.00        3     22.00      100
# 1227    AJ Men's Grooming    LIFESTYLE    5.00        2     22.00      100
# 1224       FK Dedinje BGD       SPORTS    5.00       36      2.60      100
# 1223      CB VIDEO VISION  PHOTOGRAPHY    5.00       13      2.60      100
#
#       Type Price Content_Rating       Genres
# 21    Free     0       Everyone      Medical
# 1230  Free     0       Everyone      Medical
# 1227  Free     0       Everyone    Lifestyle
# 1224  Free     0       Everyone       Sports
# 1223  Free     0       Everyone  Photography

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values(by='Size_MBs',ascending=False).head()
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by='Reviews',ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# ...

# %%
# sort apps by reviews, take first 50 by head(50) and then do value_counts on type column
# all are free!
df_apps_clean.sort_values(by='Reviews',ascending=False).head(50)['Type'].value_counts()
# Out:
# Type
# Free    50
# Name: count, dtype: int64

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
content_ratings = df_apps_clean.Content_Rating.value_counts()
content_ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=content_ratings.index, values=content_ratings.values,
             title="ContentRating",
             names=content_ratings.index)
fig.update_traces(textposition='outside', textinfo='label+percent')
fig.show()

# %%
fig = px.pie(labels=content_ratings.index, values=content_ratings.values,
             title="ContentRating",
             names=content_ratings.index, hole=0.6)
fig.update_traces(textposition='outside', textinfo='label+percent')
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size_MBs          float64
# Installs           object
# Type               object
# Price              object
# Content_Rating     object
# Genres             object
# dtype: object

# %%
# must take out comma before pandas will convert it to a numeric field from object
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(",","")
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)

# %%
df_apps_clean[['App','Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace("$","")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
# highest priced app
df_apps_clean.sort_values('Price',ascending=False).head(15) # most expensive app is 400$
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# most expensive apps dont look legit apps, so filter anything over 250
df_apps_clean = df_apps_clean[df_apps_clean.Price <= 250]
df_apps_clean.sort_values('Price',ascending=False).head(15) # most expensive app is 400$
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL    4.60
# 1407                                       LTC AS Legal      MEDICAL    4.00
# 2629                                   I am Rich Person    LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture      MEDICAL    3.50
# 2463                                 PTA Content Master      MEDICAL    4.20
# 2207                                           EMT PASS      MEDICAL    3.40
# 4264                            Golfshot Plus: Golf GPS       SPORTS    4.10
# 504                           AP Art History Flashcards       FAMILY    5.00
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL    4.20
# 2119                                         NewTek NDI  PHOTOGRAPHY    3.50
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs * df_apps_clean.Price
df_apps_clean.sort_values('Revenue_Estimate',ascending=False).head(15) # most expensive app is 400$
# Out:
#                                                    App         Category  \
# 9220                                         Minecraft           FAMILY
# 8825                                     Hitman Sniper             GAME
# 7151                     Grand Theft Auto: San Andreas             GAME
# 7477                               Facetune - For Free      PHOTOGRAPHY
# 7977                           Sleep as Android Unlock        LIFESTYLE
# 6594                               DraStic DS Emulator             GAME
# 6082                                      Weather Live          WEATHER
# 7954                                       Bloons TD 5           FAMILY
# 7633                           Five Nights at Freddy's             GAME
# 6746                        Card Wars - Adventure Time           FAMILY
# 6856                                           Threema    COMMUNICATION
# 7044                                            Tasker            TOOLS
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique()
# Out:
# 33

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]
bar = px.bar(x=top10_category.index, y=top10_category.values)
bar.show()

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs':pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)
h_bar = px.bar(x = category_installs.Installs, y=category_installs.index, orientation='h', title='Category Popularity')
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition

# %%
category_apps = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})

category_df = pd.merge(category_installs, category_apps, on='Category')
category_df.sort_values('Installs', ascending=False)
category_df.head(5)
# Out:
#            Installs  App
# Category
# EVENTS     15949410   45
# BEAUTY     26916200   42
# PARENTING  31116110   50
# MEDICAL    39162676  292
# COMICS     44931100   54

# %%
scatter = px.scatter(category_df, x='App', y='Installs', title='Category Concentration', size='App', hover_name=category_df.index, color='Installs')
scatter.update_layout(xaxis_title='Number of Apps (lower = more concentrated)', yaxis_title='Installs', yaxis=dict(type='log'))
scatter.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean.Genres.value_counts().sort_values(ascending=True) # multiple genres combined with semicolon
stack = df_apps_clean.Genres.str.split(";", expand=True).stack()
num_genres = stack.value_counts()
print(f"We have {num_genres.shape} genres.")
num_genres.head()
# Out:
# We have (53,) genres.
# Tools            719
# Education        587
# Entertainment    498
# Action           304
# Productivity     301
# Name: count, dtype: int64

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(x = num_genres.index[:15], y = num_genres.values[:15], title='Top Genres', hover_name=num_genres.index[:15], color=num_genres.values[:15], color_continuous_scale='Agsunset')
bar.update_layout(xaxis_title='Genre', yaxis_title='Number of Apps', coloraxis_showscale=False)
bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App':pd.Series.count})
df_free_vs_paid.head(10)
# Out:
#               Category  Type  App
# 0       ART_AND_DESIGN  Free   58
# 1       ART_AND_DESIGN  Paid    3
# 2    AUTO_AND_VEHICLES  Free   72
# 3    AUTO_AND_VEHICLES  Paid    1
# 4               BEAUTY  Free   42
# 5  BOOKS_AND_REFERENCE  Free  161
# 6  BOOKS_AND_REFERENCE  Paid    8
# 7             BUSINESS  Free  253
# 8             BUSINESS  Paid    9
# 9               COMICS  Free   54

# %% [markdown]
# ## Bar chart for free and paid apps by category

# %%
bar2 = px.bar(df_free_vs_paid, x='Category', y='App', title='Free vs Paid Apps by Category', color='Type', barmode='group')
bar2.update_layout(xaxis_title='Category', yaxis_title='Number of Apps', xaxis={'categoryorder':'total descending'}, yaxis=dict(type='log'))
bar2.show()

# %% [markdown]
# ## Plotly Box Plots: Lost Downloads for Paid Apps

# %%
df_free_vs_paid2 = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'Installs':pd.Series.sum})
df_free_vs_paid2.head(10)
# Out:
#               Category  Type    Installs
# 0       ART_AND_DESIGN  Free   114217100
# 1       ART_AND_DESIGN  Paid       16000
# 2    AUTO_AND_VEHICLES  Free    53079800
# 3    AUTO_AND_VEHICLES  Paid       50000
# 4               BEAUTY  Free    26916200
# 5  BOOKS_AND_REFERENCE  Free  1665769005
# 6  BOOKS_AND_REFERENCE  Paid       22650
# 7             BUSINESS  Free   691805460
# 8             BUSINESS  Paid      212660
# 9               COMICS  Free    44931100

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category

# %%
# have to filter df to onyl see paid apps
box = px.box(df_apps_clean[df_apps_clean['Type']=='Paid'], x='Category', y='Revenue_Estimate',
             points='outliers',  log_y=True, title='How much can paid apps earn?' )
box.update_layout(xaxis_title='Category', yaxis_title='Estimated Revenue', xaxis={'categoryorder':'min ascending'})

box.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
box = px.box(df_apps_clean[df_apps_clean['Type']=='Paid'], x='Category', y='Price',
             points='outliers',  log_y=True, title='Price of Paid Apps' )
box.update_layout(xaxis_title='Category', yaxis_title='Price', xaxis={'categoryorder':'max descending'})

box.show()
# Out:
#                      Price
# Category
# ART_AND_DESIGN        1.99
# AUTO_AND_VEHICLES     1.99
# BOOKS_AND_REFERENCE   3.04
# BUSINESS              4.99
# COMMUNICATION         2.70
# DATING                6.99
# EDUCATION             3.99
# ENTERTAINMENT         3.99
# FAMILY                2.99
# FINANCE               3.99
# FOOD_AND_DRINK        4.24
# GAME                  2.99
# HEALTH_AND_FITNESS    2.99
# LIFESTYLE             3.04
# MAPS_AND_NAVIGATION   2.99
# MEDICAL               5.49
# NEWS_AND_MAGAZINES    1.99
# PARENTING             4.79
# PERSONALIZATION       1.49
# PHOTOGRAPHY           2.99
# PRODUCTIVITY          3.49
# SHOPPING              2.74
# SOCIAL                0.99
# SPORTS                2.99
# TOOLS                 2.99
# TRAVEL_AND_LOCAL      3.49
# VIDEO_PLAYERS         1.74
# WEATHER               3.99

# %%
# median app prices by category
df_apps_clean[df_apps_clean['Type']=='Paid'].groupby('Category').agg({'Price':pd.Series.median})
# Out:
#                      Price
# Category
# ART_AND_DESIGN        1.99
# AUTO_AND_VEHICLES     1.99
# BOOKS_AND_REFERENCE   3.04
# BUSINESS              4.99
# COMMUNICATION         2.70
# DATING                6.99
# EDUCATION             3.99
# ENTERTAINMENT         3.99
# FAMILY                2.99
# FINANCE               3.99
# FOOD_AND_DRINK        4.24
# GAME                  2.99
# HEALTH_AND_FITNESS    2.99
# LIFESTYLE             3.04
# MAPS_AND_NAVIGATION   2.99
# MEDICAL               5.49
# NEWS_AND_MAGAZINES    1.99
# PARENTING             4.79
# PERSONALIZATION       1.49
# PHOTOGRAPHY           2.99
# PRODUCTIVITY          3.49
# SHOPPING              2.74
# SOCIAL                0.99
# SPORTS                2.99
# TOOLS                 2.99
# TRAVEL_AND_LOCAL      3.49
# VIDEO_PLAYERS         1.74
# WEATHER               3.99
